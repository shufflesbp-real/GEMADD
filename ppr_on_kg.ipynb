# %%
import pickle

# %%
with open("/path-to-folder/SD++.p","rb") as f:
    original_kg = pickle.load(f)

# %%
with open("/path-to-folder/SID.p","rb") as f:
    symptomID = pickle.load(f)

# %%
with open("/path-to-folder/DID.p","rb") as f:
    diseaseID = pickle.load(f)

# %%
diseaseID
# Out:
# {'Acanthosis nigricans': 'D_3',
#  'Acariasis': 'D_85',
#  'Acne': 'D_53',
#  'Actinic keratosis': 'D_12',
#  'Acute glaucoma': 'D_48',
#  'Acute kidney injury': 'D_86',
#  'Acute stress reaction': 'D_76',
#  'Adhesive capsulitis of the shoulder': 'D_42',
#  'Adjustment reaction': 'D_33',
#  'Air embolism': 'D_78',
#  'Alcohol intoxication': 'D_47',
#  'Allergy': 'D_28',
#  'Alzheimer disease': 'D_79',
#  'Amyloidosis': 'D_59',
#  'Amyotrophic lateral sclerosis ALS': 'D_4',
#  'Ankylosing spondylitis': 'D_75',
#  'Anxiety': 'D_82',
#  'Aphakia': 'D_50',
#  'Carbon monoxide poisoning': 'D_38',
#  'Carcinoid syndrome': 'D_44',
#  'Carpal tunnel syndrome': 'D_64',
#  'Cat scratch disease': 'D_58',
#  'Central retinal artery or vein occlusion': 'D_80',
#  'Cerebral edema': 'D_51',
#  'Chagas disease': 'D_61',
#  'Chalazion': 'D_37',
#  'Chancroid': 'D_74',
#  'Chickenpox': 'D_27',
#  'Chlamydia': 'D_23',
#  'Chondromalacia of the patella': 'D_84',
#  'Chronic back pain': 'D_19',
#  'Chronic kidney disease': 'D_7',
#  'Chronic pain disorder': 'D_56',
#  'Complex regional pain syndrome': 'D_15',
#  'Concussion': 'D_52',
#  'Conductive hearing loss': 'D_60',
#  'Conjunctivitis due to allergy': 'D_69',
#  'Connective tissue disorder': 'D_1',
#  'Contact dermatitis': 'D_55',
#  'Conversion disorder': 'D_21',
#  'Corneal abrasion': 'D_49',
#  'Corneal disorder': 'D_17',
#  'Cushing syndrome': 'D_57',
#  'Cyst of the eyelid': 'D_18',
#  'Cystic Fibrosis': 'D_87',
#  'Cystitis': 'D_34',
#  'De Quervain disease': 'D_14',
#  'Decubitus ulcer': 'D_24',
#  'Degenerative disc disease': 'D_20',
#  'Dengue fever': 'D_54',
#  'Dermatitis due to sun exposure': 'D_81',
#  'Diabetes insipidus': 'D_0',
#  'Diabetic ketoacidosis': 'D_39',
#  'Diabetic peripheral neuropathy': 'D_8',
#  'Diabetic retinopathy': 'D_41',
#  'Diaper rash': 'D_9',
#  'Dissociative disorder': 'D_26',
#  'Drug abuse cocaine': 'D_32',
#  'Drug reaction': 'D_89',
#  'Dyshidrosis': 'D_62',
#  'Eating disorder': 'D_6',
#  'Ectropion': 'D_43',
#  'Eczema': 'D_5',
#  'Encephalitis': 'D_11',
#  'Endometrial cancer': 'D_71',
#  'Endometrial hyperplasia': 'D_10',
#  'Endometriosis': 'D_36',
#  'Endophthalmitis': 'D_45',
#  'Epididymitis': 'D_13',
#  'Epidural hemorrhage': 'D_73',
#  'Erectile dysfunction': 'D_77',
#  'Erythema multiforme': 'D_16',
#  'Essential tremor': 'D_22',
#  'Extrapyramidal effect of drugs': 'D_35',
#  'Factitious disorder': 'D_46',
#  'Fat embolism': 'D_83',
#  'Female infertility of unknown cause': 'D_25',
#  'Fibrocystic breast disease': 'D_29',
#  'Fibromyalgia': 'D_63',
#  'Flat feet': 'D_30',
#  'Fluid overload': 'D_31',
#  'Fracture of the pelvis': 'D_66',
#  'Fracture of the rib': 'D_88',
#  'Ganglion cyst': 'D_2',
#  'Gas gangrene': 'D_68',
#  'Gonorrhea': 'D_67',
#  'Gout': 'D_72',
#  'Granuloma inguinale': 'D_70',
#  'Graves disease': 'D_40',
#  'Guillain Barre syndrome': 'D_65'}

# %%
symptomID_lower = {k.lower(): v for k, v in symptomID.items()}
diseaseID_lower = {k.lower(): v for k, v in diseaseID.items()}

def map_to_ids(dialogs, disease_map, symptom_map):
    result = []
    for dialog in dialogs:
        for disease, symptoms in dialog.items():
            disease_key = disease.lower()
            disease_mapped = disease_map.get(disease_key, disease)  # fallback to original if not found
            symptoms_mapped = []
            for symptom in symptoms:
                symptom_key = symptom.lower()
                symptom_mapped = symptom_map.get(symptom_key, symptom)
                symptoms_mapped.append(symptom_mapped)
            result.append({disease_mapped: symptoms_mapped})
    return result

# mapped_dialogs = map_to_ids(dialogs, diseaseID_lower, symptomID_lower)

# %%
with open("/path-to-folder/new_dialog_symptom_map.p","rb") as f:
    dialog_symptoms  = pickle.load(f)

# %%
with open("path-to-folder/new_all_self_report_file.p","rb") as f:
    test = pickle.load(f)

# %%
dialog_disease_map = {}
for item in test:
    dialog_disease_map[item['dialog_id']] = item['disease_tag']

# %%
dialogs = []

for dialogue_id, symptoms in dialog_symptoms.items():
    disease = dialog_disease_map.get(dialogue_id)
    if disease:
        dialogs.append({disease: symptoms})

# %%
with open("/path-to-folder/esmmd_disease_symptom_dialog_wise.p","wb") as f:
    pickle.dump(dialogs, f)

# %%
dialogs = map_to_ids(dialogs, diseaseID_lower, symptomID_lower)
# new_dialogs

# %%
import networkx as nx
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
symptom_disease_map = {}
for source, targets in original_kg.items():
    for target, weight in targets.items():
        if source.startswith('S_') and target.startswith('D_') and weight > 0:
            if source not in symptom_disease_map:
                symptom_disease_map[source] = []
            symptom_disease_map[source].append((target, weight))

# %%
y_true = []
y_pred = []

for dialog in dialogs:
    disease_true = list(dialog.keys())[0]
    symptoms = dialog[disease_true]

    # Create graph
    G = nx.DiGraph()

    # Add user and symptom edges
    for symptom in symptoms:
        G.add_edge("User", symptom, weight=1.0)

    # Add edges from symptoms to diseases using KG
    for symptom in symptoms:
        for (disease, weight) in symptom_disease_map.get(symptom, []):
            G.add_edge(symptom, disease, weight=weight)
    ppr = nx.pagerank(G, personalization={"User": 1.0}, alpha=0.85, weight='weight')
    disease_scores = {node: score for node, score in ppr.items() if node.startswith('D_')}

    if not disease_scores:
        predicted_disease = None
    else:
        predicted_disease = max(disease_scores, key=disease_scores.get)
    y_true.append(disease_true)
    y_pred.append(predicted_disease)
filtered_true = []
filtered_pred = []

for t, p in zip(y_true, y_pred):
    if p is not None:
        filtered_true.append(t)
        filtered_pred.append(p)

accuracy = accuracy_score(filtered_true, filtered_pred)
precision = precision_score(filtered_true, filtered_pred, average='macro', zero_division=0)
recall = recall_score(filtered_true, filtered_pred, average='macro', zero_division=0)
f1 = f1_score(filtered_true, filtered_pred, average='macro', zero_division=0)

print("Evaluation Results:")
print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Evaluation Results:
# Accuracy : 0.6569
# Precision: 0.6701
# Recall   : 0.6559
# F1 Score : 0.6106

# %% [markdown]
# ## With pruning diseases

# %%
symptom_disease_map = {}
for source, targets in original_kg.items():
    for target, weight in targets.items():
        if source.startswith('S_') and target.startswith('D_') and weight > 0:
            if source not in symptom_disease_map:
                symptom_disease_map[source] = []
            symptom_disease_map[source].append((target, weight))

y_true = []
y_pred = []

for dialog in dialogs:
    disease_true = list(dialog.keys())[0]
    symptoms = dialog[disease_true]

    # Create graph
    G = nx.DiGraph()

    # Add user and symptom edges
    for symptom in symptoms:
        G.add_edge("User", symptom, weight=1.0)

    # Find diseases connected to ALL symptoms (intersection-based filtering)
    if symptoms:
        # Get diseases for first symptom
        valid_diseases = set()
        first_symptom = symptoms[0]
        for (disease, weight) in symptom_disease_map.get(first_symptom, []):
            valid_diseases.add(disease)

        # Intersect with diseases from remaining symptoms
        for symptom in symptoms[1:]:
            symptom_diseases = set([disease for (disease, weight) in symptom_disease_map.get(symptom, [])])
            valid_diseases = valid_diseases.intersection(symptom_diseases)
    else:
        valid_diseases = set()

    # Add edges from symptoms to diseases ONLY if disease is in valid_diseases
    for symptom in symptoms:
        for (disease, weight) in symptom_disease_map.get(symptom, []):
            if disease in valid_diseases:
                G.add_edge(symptom, disease, weight=weight)

    # Run Personalized PageRank
    ppr = nx.pagerank(G, personalization={"User": 1.0}, alpha=0.85, weight='weight')

    # Filter for only disease nodes
    disease_scores = {node: score for node, score in ppr.items() if node.startswith('D_')}

    if not disease_scores:
        predicted_disease = None
    else:symptomID_lower = {k.lower(): v for k, v in symptomID.items()}
diseaseID_lower = {k.lower(): v for k, v in diseaseID.items()}
        predicted_disease = max(disease_scores, key=disease_scores.get)

    y_true.append(disease_true)
    y_pred.append(predicted_disease)

filtered_true = []
filtered_pred = []

for t, p in zip(y_true, y_pred):
    if p is not None:
        filtered_true.append(t)
        filtered_pred.append(p)

accuracy = accuracy_score(filtered_true, filtered_pred)
precision = precision_score(filtered_true, filtered_pred, average='macro', zero_division=0)
recall = recall_score(filtered_true, filtered_pred, average='macro', zero_division=0)
f1 = f1_score(filtered_true, filtered_pred, average='macro', zero_division=0)

print("Evaluation Results:")
print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Evaluation Results:
# Accuracy : 0.7445
# Precision: 0.7746
# Recall   : 0.7471
# F1 Score : 0.7130

# %% [markdown]
# ## On MDDIAL

# %%
with open("/path-to-folder/mddial_dialog_wise_disease_symptoms.p","rb") as f:
    mddial_dialogs = pickle.load(f)

# %%
with open("/path-to-folder/mddial_kg.p","rb") as f:
    mddial_kg = pickle.load(f)

# %%
with open("/path-to-folder/symptom.txt","r") as f:
    mddial_symptoms = f

# %%
symptom_file_path = "/path-to-folder/symptom.txt"
disease_file_path = "/path-to-folder/disease.txt"
with open(symptom_file_path, "r") as f:
    symptoms = [line.strip().lower() for line in f if line.strip()]
with open(disease_file_path, "r") as f:
    diseases = [line.strip().lower() for line in f if line.strip()]
symptom_dict = {symptom: f"S_{i}" for i, symptom in enumerate(symptoms)}
disease_dict = {disease: f"D_{i}" for i, disease in enumerate(diseases)}

# %%
mddial_dialogs_mapped = map_to_ids(mddial_dialogs, disease_dict, symptom_dict)

# %%
len(mddial_kg['acid reflux'])
# Out:
# 59

# %%
merged_symptom_disease_map = {**symptom_dict, **disease_dict}

# %%
merged_symptom_disease_map
# Out:
# {'dizziness': 'S_0',
#  'chest tightness': 'S_1',
#  'burning sensation behind the breastbone': 'S_2',
#  'chest tightness and shortness of breath': 'S_3',
#  'pain behind the breastbone': 'S_4',
#  'acid reflux': 'S_5',
#  'nausea': 'S_6',
#  'vomiting': 'S_7',
#  'hard to swallow': 'S_8',
#  'stomach ache': 'S_9',
#  'bloating': 'S_10',
#  'pharynx discomfort': 'S_11',
#  'expectoration': 'S_12',
#  'cough': 'S_13',
#  'fever': 'S_14',
#  'palpitations': 'S_15',
#  'diarrhea': 'S_16',
#  'feel sick and vomit': 'S_17',
#  'loss of appetite': 'S_18',
#  'hiccup': 'S_19',
#  'thin': 'S_20',
#  'anorexia': 'S_21',
#  'increased stool frequency': 'S_22',
#  'edema': 'S_23',
#  'constipation': 'S_24',
#  'bitter': 'S_25',
#  'thirst': 'S_26',
#  'hiccough': 'S_27',
#  'hemoptysis': 'S_28',
#  'runny nose': 'S_29',
#  'twitch': 'S_30',
#  'suppuration': 'S_31',
#  'chills and fever': 'S_32',
#  'black stool': 'S_33',
#  'sweating': 'S_34',
#  'shortness of breath': 'S_35',
#  'poor spirits': 'S_36',
#  'poor sleep': 'S_37',
#  'stuffy nose': 'S_38',
#  'hoarse': 'S_39',
#  'hematemesis': 'S_40',
#  'fear of cold': 'S_41',
#  'bloody stools': 'S_42',
#  'headache': 'S_43',
#  'fatigue': 'S_44',
#  'dizzy': 'S_45',
#  'syncope': 'S_46',
#  'consciousness disorder': 'S_47',
#  'sleep disorder': 'S_48',
#  'body aches': 'S_49',
#  'blood in the tears': 'S_50',
#  'diplopia': 'S_51',
#  'difficulty breathing': 'S_52',
#  'frequent urination': 'S_53',
#  'hazy': 'S_54',
#  'backache': 'S_55',
#  'night sweats': 'S_56',
#  'hematuria': 'S_57',
#  'painful urination': 'S_58',
#  'radiating pain': 'S_59',
#  'defecate': 'S_60',
#  'cyanosis': 'S_61',
#  'mucus pus and blood in the stool': 'S_62',
#  'tensile and heavy': 'S_63',
#  'rash': 'S_64',
#  'chills': 'S_65',
#  'urgency': 'S_66',
#  'decreased urine output': 'S_67',
#  'abdominal pain and diarrhea': 'S_68',
#  'sneeze': 'S_69',
#  'cry': 'S_70',
#  'waist pain': 'S_71',
#  'first degree swelling of bilateral tonsils': 'S_72',
#  'oliguria': 'S_73',
#  'afraid of cold': 'S_74',
#  'joint pain': 'S_75',
#  'itching': 'S_76',
#  'swelling of both nasal mucosa': 'S_77',
#  'itchy eyes': 'S_78',
#  'ear itching': 'S_79',
#  'thin white moss': 'S_80',
#  'nasal congestion': 'S_81',
#  'inspiratory tri-concave sign': 'S_82',
#  'tinnitus': 'S_83',
#  'vertigo': 'S_84',
#  'headache and dizziness': 'S_85',
#  'poor physical activity': 'S_86',
#  'pain in front of neck': 'S_87',
#  'redness': 'S_88',
#  'earache': 'S_89',
#  'snore': 'S_90',
#  'ulcer': 'S_91',
#  'right earache': 'S_92',
#  'nose bleeding': 'S_93',
#  'nasal mucosal congestion': 'S_94',
#  'hearing loss': 'S_95',
#  'hand tremor': 'S_96',
#  'proptosis': 'S_97',
#  'mild thyroid enlargement': 'S_98',
#  'afraid of heat': 'S_99',
#  'shaking hands': 'S_100',
#  'eye swelling': 'S_101',
#  'vision loss': 'S_102',
#  'head trauma pain': 'S_103',
#  'unconsciousness': 'S_104',
#  'incontinence': 'S_105',
#  'limb numbness': 'S_106',
#  'itchy and uncomfortable eyes': 'S_107',
#  'jealous': 'S_108',
#  'photophobia': 'S_109',
#  'papule': 'S_110',
#  'congestion of skin and mucous membranes': 'S_111',
#  'dysmenorrhea': 'S_112',
#  'breast tenderness': 'S_113',
#  'eye pain': 'S_114',
#  'lumbago': 'S_115',
#  'vaginal bleeding': 'S_116',
#  'increased vaginal discharge': 'S_117',
#  'esophagitis': 'D_0',
#  'enteritis': 'D_1',
#  'asthma': 'D_2',
#  'coronary heart disease': 'D_3',
#  'pneumonia': 'D_4',
#  'rhinitis': 'D_5',
#  'thyroiditis': 'D_6',
#  'traumatic brain injury': 'D_7',
#  'dermatitis': 'D_8',
#  'external otitis': 'D_9',
#  'conjunctivitis': 'D_10',
#  'mastitis': 'D_11'}

# %%
with open("/path-to-folder/SID.p","wb") as f:
    pickle.dump(symptom_dict,f)

# %%
with open("/path-to-folder/DID.p","wb") as f:
    pickle.dump(disease_dict,f)

# %%
mddial_kg
# Out:
# {'shortness of breath': {'esophagitis': 0.0,
#   'enteritis': 0.0,
#   'asthma': 0.0,
#   'coronary heart disease': 0.0,
#   'pneumonia': 0.0,
#   'rhinitis': 0.0,
#   'thyroiditis': 0.0,
#   'traumatic brain injury': 0.0,
#   'dermatitis': 0.0,
#   'external otitis': 0.0,
#   'conjunctivitis': 0.0,
#   'mastitis': 0.0,
#   'pain behind the breastbone': 0.0710128055878929,
#   'expectoration': 0.07159487776484284,
#   'chest tightness and shortness of breath': 0.13465987968533086,
#   'chest tightness': 0.09742539496781744,
#   'hemoptysis': 0.109375,
#   'cough': 0.0629353831371607,
#   'pharynx discomfort': 0.04317868626550299,
#   'acid reflux': 0.02471169686985173,
#   'hiccup': 0.024096385542168676,
#   'vomiting': 0.03190460844344183,
#   'nausea': 0.024828314844162706,
#   'sweating': 0.036458333333333336,
#   'diarrhea': 0.03563373928732522,
#   'stomach ache': 0.03532490187527257,
#   'hiccough': 0.037037037037037035,
#   'black stool': 0.034482758620689655,
#   'palpitations': 0.060836501901140684,
#   'fever': 0.043275942298743604,
#   'hematemesis': 0.043478260869565216,
#   'feel sick and vomit': 0.035175879396984924,
#   'bloating': 0.019748653500897665,
#   'dizziness': 0.031118587047939444,
#   'thin': 0.048582995951417005,
#   'burning sensation behind the breastbone': 0.0176678445229682,
#   'thin white moss': 0.056962025316455694,
#   'increased stool frequency': 0.047619047619047616,
#   'edema': 0.09223300970873786,
#   'headache': 0.019961051606621226,
#   'dizzy': 0.020370370370370372,
#   'cyanosis': 0.11702127659574468,
#   'defecate': 0.04878048780487805,
#   'stuffy nose': 0.04111111111111111,
#   'runny nose': 0.044623884402889925,
#   'bloody stools': 0.04,
#   'sneeze': 0.054817275747508304,
#   'loss of appetite': 0.042071197411003236,
#   'decreased urine output': 0.007575757575757576,
#   'twitch': 0.04405286343612335,
#   'difficulty breathing': 0.05088495575221239,
#   'chills': 0.0448,
#   'chills and fever': 0.045871559633027525,
#   'itching': 0.02268041237113402,
#   'fear of cold': 0.04524033930254477,
#   'rash': 0.04224058769513315,
#   'night sweats': 0.09852216748768473,
#   'first degree swelling of bilateral tonsils': 0.08080808080808081,
#   'suppuration': 0.06542056074766354,
#   'anorexia': 0.029411764705882353,
#   'fatigue': 0.021021021021021023,
#   'poor sleep': 0.02631578947368421,
#   'nasal congestion': 0.016666666666666666,
#   'inspiratory tri-concave sign': 0.08771929824561403,
#   'syncope': 0.03184713375796178,
#   'joint pain': 0.07692307692307693,
#   'poor spirits': 0.044444444444444446,
#   'hazy': 0.020942408376963352,
#   'radiating pain': 0.012987012987012988,
#   'pain in front of neck': 0.012738853503184714,
#   'consciousness disorder': 0.004640371229698376,
#   'hoarse': 0.05202312138728324,
#   'oliguria': 0.07142857142857142,
#   'body aches': 0.023809523809523808,
#   'proptosis': 0.023255813953488372,
#   'shaking hands': 0.057692307692307696,
#   'constipation': 0.023809523809523808,
#   'hard to swallow': 0.013793103448275862,
#   'afraid of heat': 0.03389830508474576,
#   'afraid of cold': 0.023255813953488372,
#   'mild thyroid enlargement': 0.007462686567164179,
#   'frequent urination': 0.024305555555555556,
#   'hand tremor': 0.04225352112676056,
#   'head trauma pain': 0.010416666666666666,
#   'incontinence': 0.014492753623188406,
#   'unconsciousness': 0.0273972602739726,
#   'headache and dizziness': 0.00546448087431694,
#   'vertigo': 0.002512562814070352,
#   'poor physical activity': 0.041666666666666664,
#   'painful urination': 0.02040816326530612,
#   'urgency': 0.022641509433962263,
#   'congestion of skin and mucous membranes': 0.021739130434782608,
#   'ear itching': 0.0015455950540958269,
#   'earache': 0.002285714285714286,
#   'right earache': 0.0016181229773462784,
#   'tinnitus': 0.010428736964078795,
#   'itchy and uncomfortable eyes': 0.01079913606911447,
#   'cry': 0.006279434850863423,
#   'jealous': 0.007168458781362007,
#   'photophobia': 0.007974481658692184,
#   'breast tenderness': 0.043235704323570434,
#   'abdominal pain and diarrhea': 0.008,
#   'lumbago': 0.05555555555555555,
#   'redness': 0.014925373134328358,
#   'thirst': 0.004878048780487805,
#   'mucus pus and blood in the stool': 0.007874015748031496,
#   'tensile and heavy': 0.010101010101010102,
#   'hearing loss': 0.001349527665317139},
#  'esophagitis': {'shortness of breath': 0.0,
#   'pain behind the breastbone': 0.06044355958930016,
#   'expectoration': 0.008511982531594211,
#   'chest tightness and shortness of breath': 0.0,
#   'chest tightness': 0.0,
#   'hemoptysis': 0.015068416968694463,
#   'cough': 0.0,
#   'acid reflux': 0.33101415534126966,
#   'burning sensation behind the breastbone': 0.37018457552947176,
#   'vomiting': 0.0,
#   'nausea': 0.0,
#   'bloating': 0.07192051811294521,
#   'diarrhea': 0.016078189226344616,
#   'stomach ache': 0.0,
#   'hiccough': 0.10150222232259709,
#   'pharynx discomfort': 0.01796974090003222,
#   'hiccup': 0.12808154423390292,
#   'fatigue': 0.0014186637552657017,
#   'sweating': 0.022036147179791542,
#   'fever': 0.0,
#   'consciousness disorder': 0.002972634078162303,
#   'twitch': 0.006253958096777844,
#   'hard to swallow': 0.13561575271825016,
#   'bitter': 0.05273945939043062,
#   'thirst': 0.01427394680468315,
#   'poor sleep': 0.004407229435958308,
#   'thin': 0.03806385814582173,
#   'palpitations': 0.0,
#   'black stool': 0.08359006544213879,
#   'sleep disorder': 0.00292932880832982,
#   'headache': 0.0,
#   'dizziness': 0.0,
#   'feel sick and vomit': 0.00891790223448691,
#   'hematemesis': 0.045205250906083384,
#   'fear of cold': 0.002364439592109503,
#   'constipation': 0.017912156880458312,
#   'runny nose': 0.0,
#   'syncope': 0.0037671042421736156,
#   'dizzy': 0.0,
#   'thin white moss': 0.022602625453041692,
#   'poor spirits': 0.007534208484347231,
#   'edema': 0.004407229435958308,
#   'diplopia': 0.004757982268227716,
#   'blood in the tears': 0.009737823202326386,
#   'stuffy nose': 0.0,
#   'anorexia': 0.00585865761665964,
#   'increased stool frequency': 0.019475646404652772,
#   'hoarse': 0.009380937145166766,
#   'difficulty breathing': 0.0,
#   'body aches': 0.0037671042421736156,
#   'loss of appetite': 0.001563489524194461,
#   'limb numbness': 0.009737823202326386,
#   'frequent urination': 0.002203614717979154,
#   'bloody stools': 0.007534208484347231},
#  'enteritis': {'shortness of breath': 0.0,
#   'pain behind the breastbone': 0.005064487688720961,
#   'expectoration': 0.0009667930776625522,
#   'chest tightness and shortness of breath': 0.0,
#   'chest tightness': 0.0,
#   'cough': 0.0,
#   'acid reflux': 0.008983275012211448,
#   'vomiting': 0.0,
#   'nausea': 0.0,
#   'bloating': 0.027169973509334856,
#   'diarrhea': 0.06864230851404121,
#   'stomach ache': 0.0,
#   'hiccough': 0.006103401603711721,
#   'pharynx discomfort': 0.013051706548444455,
#   'fatigue': 0.003867172310650209,
#   'sweating': 0.0022525839339342466,
#   'fever': 0.0,
#   'consciousness disorder': 0.0010128975377441923,
#   'twitch': 0.03675937592439422,
#   'thirst': 0.11186544977299831,
#   'palpitations': 0.0,
#   'black stool': 0.018310204811135163,
#   'sleep disorder': 0.002994425004070483,
#   'headache': 0.0,
#   'dizziness': 0.0,
#   'feel sick and vomit': 0.010128975377441922,
#   'hematemesis': 0.007701635339554948,
#   'fear of cold': 0.00870113769896297,
#   'constipation': 0.006103401603711721,
#   'runny nose': 0.0,
#   'dizzy': 0.0,
#   'poor spirits': 0.011552453009332421,
#   'edema': 0.0022525839339342466,
#   'stuffy nose': 0.0,
#   'anorexia': 0.008983275012211448,
#   'increased stool frequency': 0.06967953491442436,
#   'hoarse': 0.001598233735843227,
#   'difficulty breathing': 0.0,
#   'body aches': 0.007701635339554948,
#   'loss of appetite': 0.027169973509334856,
#   'frequent urination': 0.00675775180180274,
#   'bloody stools': 0.053911447376884636,
#   'cyanosis': 0.003850817669777474,
#   'defecate': 0.12322616543287916,
#   'abdominal pain and diarrhea': 0.06931471805599453,
#   'mucus pus and blood in the stool': 0.2622957019220667,
#   'chills': 0.012154770452930307,
#   'suppuration': 0.03080654135821979,
#   'decreased urine output': 0.31751584969513336,
#   'sneeze': 0.006392934943372908,
#   'rash': 0.011187636150902588,
#   'cry': 0.005988850008140966,
#   'chills and fever': 0.00675775180180274,
#   'backache': 0.006103401603711721,
#   'tensile and heavy': 0.17946548026246667,
#   'night sweats': 0.007701635339554948,
#   'headache and dizziness': 0.007701635339554948,
#   'oliguria': 0.009954219273489195,
#   'first degree swelling of bilateral tonsils': 0.012206803207423442,
#   'waist pain': 0.003850817669777474,
#   'lumbago': 0.007701635339554948,
#   'urgency': 0.014591145622564998,
#   'painful urination': 0.003850817669777474},
#  'asthma': {'shortness of breath': 0.0,
#   'pain behind the breastbone': 0.05459346050892426,
#   'expectoration': 0.042276714243548896,
#   'chest tightness and shortness of breath': 0.0,
#   'chest tightness': 0.0,
#   'hemoptysis': 0.09006997261513414,
#   'cough': 0.0,
#   'acid reflux': 0.006090355940482338,
#   'burning sensation behind the breastbone': 0.0062068490885203945,
#   'vomiting': 0.0,
#   'nausea': 0.0,
#   'diarrhea': 0.0058990764060765895,
#   'stomach ache': 0.0,
#   'pharynx discomfort': 0.030478561431395712,
#   'fatigue': 0.0024579485025319125,
#   'sweating': 0.0022907633226449966,
#   'fever': 0.0,
#   'consciousness disorder': 0.0010300652926212123,
#   'twitch': 0.0032506448864608006,
#   'poor sleep': 0.004581526645289993,
#   'palpitations': 0.0,
#   'headache': 0.0,
#   'dizziness': 0.0,
#   'feel sick and vomit': 0.0020601305852424247,
#   'fear of cold': 0.00786543520810212,
#   'runny nose': 0.0,
#   'syncope': 0.007832171531750793,
#   'dizzy': 0.0,
#   'poor spirits': 0.003916085765875397,
#   'edema': 0.009163053290579986,
#   'diplopia': 0.00494615105849661,
#   'stuffy nose': 0.0,
#   'anorexia': 0.003045177970241169,
#   'difficulty breathing': 0.0,
#   'body aches': 0.003916085765875397,
#   'loss of appetite': 0.0016253224432304003,
#   'cyanosis': 0.007832171531750793,
#   'chills': 0.0020601305852424247,
#   'suppuration': 0.02349651459525238,
#   'sneeze': 0.026005159091686405,
#   'rash': 0.008126612216152001,
#   'chills and fever': 0.004581526645289993,
#   'night sweats': 0.054825200722255565,
#   'first degree swelling of bilateral tonsils': 0.037241094531122364,
#   'itching': 0.012413698177040789,
#   'nasal congestion': 0.007832171531750793,
#   'inspiratory tri-concave sign': 0.012413698177040789,
#   'nasal mucosal congestion': 0.007832171531750793,
#   'joint pain': 0.01012293485439579,
#   'incontinence': 0.007832171531750793,
#   'vertigo': 0.003045177970241169},
#  'coronary heart disease': {'shortness of breath': 0.0,
#   'pain behind the breastbone': 0.10660331462815924,
#   'expectoration': 0.0190188802163125,
#   'chest tightness and shortness of breath': 0.0,
#   'chest tightness': 0.0,
#   'hemoptysis': 0.034089205601308785,
#   'cough': 0.0,
#   'acid reflux': 0.02061735248704267,
#   'burning sensation behind the breastbone': 0.012006691679432894,
#   'vomiting': 0.0,
#   'nausea': 0.0,
#   'bloating': 0.011004232279576316,
#   'diarrhea': 0.006656608075709376,
#   'stomach ache': 0.0,
#   'hiccough': 0.006003345839716447,
#   'pharynx discomfort': 0.0023773600270390626,
#   'hiccup': 0.007575379022513064,
#   'fatigue': 0.008558496097340626,
#   'sweating': 0.04209747024073838,
#   'fever': 0.0,
#   'consciousness disorder': 0.004981463300381273,
#   'twitch': 0.0047160995483898505,
#   'bitter': 0.007575379022513064,
#   'poor sleep': 0.0022156563284599145,
#   'palpitations': 0.0,
#   'black stool': 0.006003345839716447,
#   'headache': 0.0,
#   'dizziness': 0.0,
#   'feel sick and vomit': 0.01295180458099131,
#   'fear of cold': 0.007132080081117188,
#   'constipation': 0.006003345839716447,
#   'runny nose': 0.0,
#   'syncope': 0.07575379022513062,
#   'dizzy': 0.0,
#   'edema': 0.037666157583818555,
#   'stuffy nose': 0.0,
#   'anorexia': 0.002945336069577524,
#   'difficulty breathing': 0.0,
#   'body aches': 0.003787689511256532,
#   'frequent urination': 0.0066469689853797444,
#   'chills': 0.008966633940686291,
#   'sneeze': 0.0015720331827966166,
#   'chills and fever': 0.01994090695613923,
#   'backache': 0.060033458397164466,
#   'night sweats': 0.030301516090052254,
#   'waist pain': 0.03787689511256531,
#   'urgency': 0.014351946513998359,
#   'painful urination': 0.003787689511256532,
#   'vertigo': 0.01472668034788762,
#   'radiating pain': 0.09791035350972978,
#   'hazy': 0.09090454827015676,
#   'tinnitus': 0.008836008208732572,
#   'hematuria': 0.009791035350972978,
#   'pain in front of neck': 0.007575379022513064},
#  'pneumonia': {'shortness of breath': 0.0,
#   'pain behind the breastbone': 0.014840126715787003,
#   'expectoration': 0.020741084049853593,
#   'chest tightness and shortness of breath': 0.0,
#   'chest tightness': 0.0,
#   'hemoptysis': 0.03626932921534597,
#   'cough': 0.0,
#   'acid reflux': 0.0031337005856551564,
#   'vomiting': 0.0,
#   'nausea': 0.0,
#   'bloating': 0.006690280754692577,
#   'diarrhea': 0.024788124840068926,
#   'stomach ache': 0.0,
#   'pharynx discomfort': 0.025294004938845843,
#   'fatigue': 0.0015176402963307505,
#   'sweating': 0.00235735527969863,
#   'fever': 0.0,
#   'consciousness disorder': 0.002120018102255286,
#   'twitch': 0.05686738641488691,
#   'hard to swallow': 0.004029925468371775,
#   'bitter': 0.00805985093674355,
#   'thirst': 0.005089934519499417,
#   'poor sleep': 0.00471471055939726,
#   'thin': 0.005089934519499417,
#   'palpitations': 0.0,
#   'black stool': 0.0063872807480704055,
#   'sleep disorder': 0.0031337005856551564,
#   'headache': 0.0,
#   'dizziness': 0.0,
#   'feel sick and vomit': 0.002120018102255286,
#   'fear of cold': 0.003541160691438418,
#   'runny nose': 0.0,
#   'dizzy': 0.0,
#   'poor spirits': 0.02417955281023065,
#   'stuffy nose': 0.0,
#   'anorexia': 0.006267401171310313,
#   'hoarse': 0.011707991320712012,
#   'difficulty breathing': 0.0,
#   'loss of appetite': 0.025088552830097168,
#   'frequent urination': 0.00235735527969863,
#   'bloody stools': 0.00805985093674355,
#   'cyanosis': 0.08865836030417905,
#   'defecate': 0.02417955281023065,
#   'chills': 0.020140171971425216,
#   'suppuration': 0.04029925468371775,
#   'sneeze': 0.020070842264077734,
#   'rash': 0.03679654415080918,
#   'chills and fever': 0.007072065839095891,
#   'night sweats': 0.020149627341858874,
#   'oliguria': 0.04166882486576872,
#   'first degree swelling of bilateral tonsils': 0.031936403740352025,
#   'lumbago': 0.00805985093674355,
#   'urgency': 0.005089934519499417,
#   'painful urination': 0.004029925468371775,
#   'nasal congestion': 0.00805985093674355,
#   'inspiratory tri-concave sign': 0.012774561496140811,
#   'earache': 0.004029925468371775,
#   'hand tremor': 0.01041720621644218},
#  'rhinitis': {'shortness of breath': 0.0,
#   'pain behind the breastbone': 0.010185561832064502,
#   'expectoration': 0.010208038641241474,
#   'chest tightness and shortness of breath': 0.0,
#   'chest tightness': 0.0,
#   'hemoptysis': 0.019361653088266626,
#   'cough': 0.0,
#   'burning sensation behind the breastbone': 0.006137498819374915,
#   'vomiting': 0.0,
#   'nausea': 0.0,
#   'diarrhea': 0.002430485390771779,
#   'stomach ache': 0.0,
#   'pharynx discomfort': 0.03354069839265055,
#   'fatigue': 0.0014582912344630675,
#   'sweating': 0.0045303364034431776,
#   'fever': 0.0,
#   'consciousness disorder': 0.0010185561832064503,
#   'hard to swallow': 0.030978644941226607,
#   'thirst': 0.014672660402579326,
#   'thin': 0.009781773601719551,
#   'palpitations': 0.0,
#   'sleep disorder': 0.0030111536353781393,
#   'headache': 0.0,
#   'dizziness': 0.0,
#   'fear of cold': 0.002430485390771779,
#   'runny nose': 0.0,
#   'syncope': 0.003872330617653326,
#   'dizzy': 0.0,
#   'thin white moss': 0.015489322470613303,
#   'edema': 0.0045303364034431776,
#   'diplopia': 0.058690641610317305,
#   'blood in the tears': 0.07006880605919769,
#   'stuffy nose': 0.0,
#   'hoarse': 0.02089311140711258,
#   'difficulty breathing': 0.0,
#   'body aches': 0.023233983705919954,
#   'frequent urination': 0.0022651682017215888,
#   'cyanosis': 0.003872330617653326,
#   'chills': 0.0020371123664129007,
#   'suppuration': 0.034850975558879935,
#   'sneeze': 0.12053718119488024,
#   'rash': 0.0032143248318634732,
#   'cry': 0.006022307270756279,
#   'chills and fever': 0.0022651682017215888,
#   'backache': 0.006137498819374915,
#   'night sweats': 0.007744661235306652,
#   'headache and dizziness': 0.007744661235306652,
#   'first degree swelling of bilateral tonsils': 0.030687494096874574,
#   'waist pain': 0.003872330617653326,
#   'painful urination': 0.003872330617653326,
#   'itching': 0.006137498819374915,
#   'nasal congestion': 0.10842525729429311,
#   'inspiratory tri-concave sign': 0.01227499763874983,
#   'nasal mucosal congestion': 0.08519127358837315,
#   'vertigo': 0.0030111536353781393,
#   'tinnitus': 0.0030111536353781393,
#   'earache': 0.011616991852959977,
#   'itchy eyes': 0.03682499291624949,
#   'snore': 0.10009829437028239,
#   'nose bleeding': 0.13165924100021306,
#   'hearing loss': 0.015489322470613303,
#   'swelling of both nasal mucosa': 0.08007863549622592,
#   'ulcer': 0.02001965887405648},
#  'thyroiditis': {'shortness of breath': 0.0,
#   'pain behind the breastbone': 0.009484936480610355,
#   'expectoration': 0.0050295593635624105,
#   'chest tightness and shortness of breath': 0.0,
#   'chest tightness': 0.0,
#   'hemoptysis': 0.004006631101502574,
#   'cough': 0.0,
#   'acid reflux': 0.006231173418874992,
#   'vomiting': 0.0,
#   'nausea': 0.0,
#   'bloating': 0.004988706458701401,
#   'stomach ache': 0.0,
#   'hiccough': 0.01905108015031404,
#   'pharynx discomfort': 0.02062119339060588,
#   'hiccup': 0.008013262203005148,
#   'fatigue': 0.03218917992679943,
#   'sweating': 0.0749993263552674,
#   'fever': 0.0,
#   'consciousness disorder': 0.0010538818311789282,
#   'hard to swallow': 0.04407294211652831,
#   'thirst': 0.020242051730726008,
#   'poor sleep': 0.011718644743010532,
#   'thin': 0.06072615519217802,
#   'palpitations': 0.0,
#   'sleep disorder': 0.052964974060437445,
#   'headache': 0.0,
#   'dizziness': 0.0,
#   'fear of cold': 0.001508867809068723,
#   'constipation': 0.044452520350732765,
#   'runny nose': 0.0,
#   'syncope': 0.004006631101502574,
#   'dizzy': 0.0,
#   'poor spirits': 0.012019893304507721,
#   'edema': 0.01874983158881685,
#   'stuffy nose': 0.0,
#   'anorexia': 0.028040280384937468,
#   'hoarse': 0.018291923681905138,
#   'difficulty breathing': 0.0,
#   'loss of appetite': 0.019954825834805606,
#   'frequent urination': 0.004687457897204213,
#   'chills': 0.0010538818311789282,
#   'sneeze': 0.0016629021529004672,
#   'rash': 0.0016629021529004672,
#   'cry': 0.003115586709437496,
#   'chills and fever': 0.0023437289486021064,
#   'backache': 0.00635036005010468,
#   'night sweats': 0.008013262203005148,
#   'radiating pain': 0.010356991151607254,
#   'tinnitus': 0.003115586709437496,
#   'pain in front of neck': 0.6090079274283913,
#   'earache': 0.008013262203005148,
#   'hand tremor': 0.17606884957732333,
#   'mild thyroid enlargement': 0.4309086675932948,
#   'proptosis': 0.4596359120995145,
#   'afraid of cold': 0.10356991151607253,
#   'afraid of heat': 0.12428389381928703,
#   'shaking hands': 0.18672708929042778,
#   'eye swelling': 0.051784955758036266,
#   'right earache': 0.020713982303214508,
#   'vision loss': 0.010356991151607254},
#  'traumatic brain injury': {'shortness of breath': 0.0,
#   'pain behind the breastbone': 0.006077385226465153,
#   'chest tightness and shortness of breath': 0.0,
#   'chest tightness': 0.0,
#   'cough': 0.0,
#   'vomiting': 0.0,
#   'nausea': 0.0,
#   'bloating': 0.006392934943372908,
#   'diarrhea': 0.0014501896164938284,
#   'stomach ache': 0.0,
#   'fatigue': 0.0009667930776625522,
#   'fever': 0.0,
#   'consciousness disorder': 0.06988993010434927,
#   'twitch': 0.017580571094275497,
#   'poor sleep': 0.0022525839339342466,
#   'palpitations': 0.0,
#   'sleep disorder': 0.002994425004070483,
#   'headache': 0.0,
#   'dizziness': 0.0,
#   'feel sick and vomit': 0.027348233519093188,
#   'hematemesis': 0.007701635339554948,
#   'fear of cold': 0.0009667930776625522,
#   'runny nose': 0.0,
#   'syncope': 0.003850817669777474,
#   'dizzy': 0.0,
#   'poor spirits': 0.023104906018664842,
#   'stuffy nose': 0.0,
#   'anorexia': 0.005988850008140966,
#   'difficulty breathing': 0.0,
#   'loss of appetite': 0.001598233735843227,
#   'limb numbness': 0.01990843854697839,
#   'cry': 0.04192195005698676,
#   'headache and dizziness': 0.2772588722239781,
#   'waist pain': 0.003850817669777474,
#   'incontinence': 0.09241962407465937,
#   'vertigo': 0.017966550024422896,
#   'hazy': 0.007701635339554948,
#   'tinnitus': 0.008983275012211448,
#   'pain in front of neck': 0.023104906018664842,
#   'earache': 0.003850817669777474,
#   'nose bleeding': 0.007701635339554948,
#   'hearing loss': 0.007701635339554948,
#   'unconsciousness': 0.19327051720573338,
#   'head trauma pain': 0.7730820688229335,
#   'redness': 0.004863715207521666,
#   'poor physical activity': 0.05522014777306668},
#  'dermatitis': {'shortness of breath': 0.0,
#   'pain behind the breastbone': 0.006215507617975724,
#   'expectoration': 0.004943828238047142,
#   'chest tightness and shortness of breath': 0.0,
#   'chest tightness': 0.0,
#   'cough': 0.0,
#   'acid reflux': 0.006124960235598715,
#   'vomiting': 0.0,
#   'nausea': 0.0,
#   'bloating': 0.006538228919358656,
#   'diarrhea': 0.02274160989501685,
#   'stomach ache': 0.0,
#   'pharynx discomfort': 0.009887656476094284,
#   'fatigue': 0.004943828238047142,
#   'fever': 0.0,
#   'consciousness disorder': 0.0010359179363292875,
#   'twitch': 0.014711015068556975,
#   'hard to swallow': 0.003938336253181508,
#   'poor sleep': 0.009215116093367373,
#   'palpitations': 0.0,
#   'headache': 0.0,
#   'dizziness': 0.0,
#   'feel sick and vomit': 0.0010359179363292875,
#   'fear of cold': 0.008898890828484857,
#   'runny nose': 0.0,
#   'dizzy': 0.0,
#   'edema': 0.006911337070025529,
#   'stuffy nose': 0.0,
#   'hoarse': 0.006538228919358656,
#   'difficulty breathing': 0.0,
#   'loss of appetite': 0.001634557229839664,
#   'frequent urination': 0.009215116093367373,
#   'cyanosis': 0.011815008759544521,
#   'defecate': 0.007876672506363015,
#   'abdominal pain and diarrhea': 0.06301338005090412,
#   'chills': 0.005179589681646437,
#   'suppuration': 0.01575334501272603,
#   'sneeze': 0.00817278614919832,
#   'rash': 0.24681814170578922,
#   'cry': 0.0030624801177993573,
#   'waist pain': 0.003938336253181508,
#   'urgency': 0.01989701675804318,
#   'painful urination': 0.007876672506363015,
#   'itching': 0.9800120984141661,
#   'joint pain': 0.020360903059409716,
#   'vertigo': 0.0030624801177993573,
#   'tinnitus': 0.0030624801177993573,
#   'hematuria': 0.010180451529704858,
#   'earache': 0.003938336253181508,
#   'itchy eyes': 0.006242115276523351,
#   'snore': 0.010180451529704858,
#   'ulcer': 0.020360903059409716,
#   'redness': 0.004974254189510795,
#   'congestion of skin and mucous membranes': 0.16942545339463638,
#   'papule': 0.05647515113154546,
#   'dysmenorrhea': 0.014118787782886366,
#   'breast tenderness': 0.007876672506363015,
#   'photophobia': 0.020360903059409716,
#   'jealous': 0.020360903059409716,
#   'eye pain': 0.010180451529704858,
#   'itchy and uncomfortable eyes': 0.010180451529704858},
#  'external otitis': {'shortness of breath': 0.0,
#   'expectoration': 0.0025441923096382953,
#   'chest tightness and shortness of breath': 0.0,
#   'chest tightness': 0.0,
#   'cough': 0.0,
#   'vomiting': 0.0,
#   'nausea': 0.0,
#   'diarrhea': 0.0010176769238553181,
#   'stomach ache': 0.0,
#   'pharynx discomfort': 0.010176769238553181,
#   'fever': 0.0,
#   'hard to swallow': 0.008106984567952577,
#   'poor sleep': 0.0023711409830886807,
#   'palpitations': 0.0,
#   'sleep disorder': 0.003152026320074192,
#   'headache': 0.0,
#   'dizziness': 0.0,
#   'feel sick and vomit': 0.003198623803402712,
#   'fear of cold': 0.0015265153857829772,
#   'runny nose': 0.0,
#   'dizzy': 0.0,
#   'diplopia': 0.015359100655331576,
#   'stuffy nose': 0.0,
#   'hoarse': 0.0033647026017752145,
#   'difficulty breathing': 0.0,
#   'chills': 0.0010662079344675706,
#   'sneeze': 0.0033647026017752145,
#   'rash': 0.0033647026017752145,
#   'cry': 0.006304052640148384,
#   'chills and fever': 0.0023711409830886807,
#   'itching': 0.629614060172367,
#   'nasal mucosal congestion': 0.008106984567952577,
#   'vertigo': 0.15444928968363542,
#   'tinnitus': 0.3908512636891998,
#   'earache': 0.5796493966086093,
#   'itchy eyes': 0.006424633267064969,
#   'nose bleeding': 0.02432095370385773,
#   'hearing loss': 0.9809451327222618,
#   'swelling of both nasal mucosa': 0.02095625110208251,
#   'right earache': 0.9849438017978781,
#   'redness': 0.030718201310663152,
#   'ear itching': 1.4240985478317194},
#  'conjunctivitis': {'shortness of breath': 0.0,
#   'expectoration': 0.0005338121287707344,
#   'chest tightness and shortness of breath': 0.0,
#   'chest tightness': 0.0,
#   'cough': 0.0,
#   'vomiting': 0.0,
#   'nausea': 0.0,
#   'bloating': 0.001764920689888226,
#   'diarrhea': 0.0037366849013951405,
#   'stomach ache': 0.0,
#   'pharynx discomfort': 0.010676242575414687,
#   'fatigue': 0.0005338121287707344,
#   'sweating': 0.0024875160006635855,
#   'fever': 0.0,
#   'twitch': 0.007059682759552904,
#   'palpitations': 0.0,
#   'headache': 0.0,
#   'dizziness': 0.0,
#   'feel sick and vomit': 0.0022370743164902406,
#   'runny nose': 0.0,
#   'dizzy': 0.0,
#   'edema': 0.0024875160006635855,
#   'diplopia': 0.005370973848796931,
#   'stuffy nose': 0.0,
#   'hoarse': 0.005294762069664678,
#   'difficulty breathing': 0.0,
#   'loss of appetite': 0.001764920689888226,
#   'cyanosis': 0.021262183452759056,
#   'chills': 0.0022370743164902406,
#   'sneeze': 0.001764920689888226,
#   'rash': 0.005294762069664678,
#   'cry': 0.39680723980320504,
#   'inspiratory tri-concave sign': 0.006739952691215398,
#   'hazy': 0.16159259424096883,
#   'itchy eyes': 0.2493782495749697,
#   'afraid of heat': 0.010992389381767208,
#   'eye swelling': 0.1648858407265081,
#   'vision loss': 0.4726727434159899,
#   'redness': 0.005370973848796931,
#   'breast tenderness': 0.008504873381103624,
#   'photophobia': 1.4509953983932715,
#   'jealous': 1.264124778903229,
#   'eye pain': 0.6485509735242653,
#   'itchy and uncomfortable eyes': 0.9453454868319798},
#  'mastitis': {'shortness of breath': 0.0,
#   'pain behind the breastbone': 0.02071835872658575,
#   'expectoration': 0.021752844247407425,
#   'chest tightness and shortness of breath': 0.0,
#   'chest tightness': 0.0,
#   'cough': 0.0,
#   'vomiting': 0.0,
#   'nausea': 0.0,
#   'bloating': 0.021249243987915632,
#   'diarrhea': 0.018292164480774427,
#   'stomach ache': 0.0,
#   'pharynx discomfort': 0.02125846142360271,
#   'fatigue': 0.005438211061851856,
#   'fever': 0.0,
#   'consciousness disorder': 0.007251425554305012,
#   'twitch': 0.013076457838717312,
#   'thin': 0.059691050274129534,
#   'palpitations': 0.0,
#   'headache': 0.0,
#   'dizziness': 0.0,
#   'feel sick and vomit': 0.003107753808987862,
#   'fear of cold': 0.036584328961548854,
#   'runny nose': 0.0,
#   'dizzy': 0.0,
#   'thin white moss': 0.09452007007635617,
#   'stuffy nose': 0.0,
#   'hoarse': 0.003269114459679328,
#   'difficulty breathing': 0.0,
#   'body aches': 0.03150669002545206,
#   'loss of appetite': 0.003269114459679328,
#   'frequent urination': 0.041468022420153176,
#   'abdominal pain and diarrhea': 0.023630017519089042,
#   'chills': 0.03418529189886649,
#   'suppuration': 0.003938336253181508,
#   'rash': 0.003269114459679328,
#   'chills and fever': 0.04607558046683686,
#   'waist pain': 0.019691681265907535,
#   'lumbago': 0.03150669002545206,
#   'urgency': 0.0845623212216835,
#   'painful urination': 0.08664339756999316,
#   'incontinence': 0.007876672506363015,
#   'vertigo': 0.0030624801177993573,
#   'tinnitus': 0.021437360824595502,
#   'afraid of cold': 0.010180451529704858,
#   'redness': 0.029845525137064767,
#   'breast tenderness': 0.9058173382317467},
#  'pain behind the breastbone': {'esophagitis': 0.06044355958930016,
#   'enteritis': 0.005064487688720961,
#   'asthma': 0.05459346050892426,
#   'coronary heart disease': 0.10660331462815924,
#   'pneumonia': 0.014840126715787003,
#   'rhinitis': 0.010185561832064502,
#   'thyroiditis': 0.009484936480610355,
#   'traumatic brain injury': 0.006077385226465153,
#   'dermatitis': 0.006215507617975724,
#   'mastitis': 0.02071835872658575,
#   'shortness of breath': 0.0710128055878929,
#   'expectoration': 0.04074505238649592,
#   'chest tightness and shortness of breath': 0.03887089310504396,
#   'chest tightness': 0.06173200702165009,
#   'hemoptysis': 0.103125,
#   'cough': 0.025702618304107614,
#   'acid reflux': 0.054365733113673806,
#   'burning sensation behind the breastbone': 0.04240282685512368,
#   'hiccough': 0.046296296296296294,
#   'stomach ache': 0.04099433057130397,
#   'vomiting': 0.019980663873670642,
#   'nausea': 0.02746962493396725,
#   'sweating': 0.057291666666666664,
#   'diarrhea': 0.02165087956698241,
#   'pharynx discomfort': 0.018373909049150206,
#   'consciousness disorder': 0.037122969837587005,
#   'twitch': 0.01762114537444934,
#   'hiccup': 0.07228915662650602,
#   'thin': 0.020242914979757085,
#   'fever': 0.021715526601520086,
#   'headache': 0.021421616358325218,
#   'dizziness': 0.03532380151387721,
#   'feel sick and vomit': 0.05527638190954774,
#   'hard to swallow': 0.05172413793103448,
#   'syncope': 0.10828025477707007,
#   'bloating': 0.03231597845601436,
#   'dizzy': 0.03518518518518519,
#   'hematemesis': 0.08695652173913043,
#   'black stool': 0.05172413793103448,
#   'palpitations': 0.060836501901140684,
#   'thin white moss': 0.0189873417721519,
#   'poor spirits': 0.022222222222222223,
#   'hoarse': 0.008670520231213872,
#   'body aches': 0.023809523809523808,
#   'stuffy nose': 0.008888888888888889,
#   'edema': 0.03398058252427184,
#   'loss of appetite': 0.003236245954692557,
#   'backache': 0.11904761904761904,
#   'abdominal pain and diarrhea': 0.016,
#   'difficulty breathing': 0.048672566371681415,
#   'runny nose': 0.009774755631109222,
#   'night sweats': 0.04433497536945813,
#   'fear of cold': 0.02639019792648445,
#   'fatigue': 0.024024024024024024,
#   'rash': 0.006427915518824609,
#   'joint pain': 0.07692307692307693,
#   'sneeze': 0.008305647840531562,
#   'waist pain': 0.0660377358490566,
#   'radiating pain': 0.11688311688311688,
#   'chills': 0.0112,
#   'chills and fever': 0.01529051987767584,
#   'anorexia': 0.00980392156862745,
#   'hazy': 0.04712041884816754,
#   'vertigo': 0.002512562814070352,
#   'poor sleep': 0.02631578947368421,
#   'frequent urination': 0.024305555555555556,
#   'painful urination': 0.027210884353741496,
#   'urgency': 0.026415094339622643,
#   'hand tremor': 0.04225352112676056,
#   'pain in front of neck': 0.0031847133757961785,
#   'earache': 0.001142857142857143,
#   'unconsciousness': 0.0136986301369863,
#   'tinnitus': 0.002317497103128621,
#   'incontinence': 0.014492753623188406,
#   'head trauma pain': 0.010416666666666666,
#   'itching': 0.004123711340206186,
#   'breast tenderness': 0.019525801952580194,
#   'bitter': 0.02,
#   'thirst': 0.004878048780487805,
#   'sleep disorder': 0.012345679012345678},
#  'expectoration': {'esophagitis': 0.008511982531594211,
#   'enteritis': 0.0009667930776625522,
#   'asthma': 0.042276714243548896,
#   'coronary heart disease': 0.0190188802163125,
#   'pneumonia': 0.020741084049853593,
#   'rhinitis': 0.010208038641241474,
#   'thyroiditis': 0.0050295593635624105,
#   'dermatitis': 0.004943828238047142,
#   'external otitis': 0.0025441923096382953,
#   'conjunctivitis': 0.0005338121287707344,
#   'mastitis': 0.021752844247407425,
#   'shortness of breath': 0.07159487776484284,
#   'pain behind the breastbone': 0.04074505238649592,
#   'chest tightness and shortness of breath': 0.031004164738546967,
#   'chest tightness': 0.03832650672908133,
#   'hemoptysis': 0.084375,
#   'cough': 0.049243334134037954,
#   'stomach ache': 0.01831661578717837,
#   'fever': 0.032883511710873274,
#   'acid reflux': 0.016474464579901153,
#   'hiccup': 0.012048192771084338,
#   'vomiting': 0.011923944569771189,
#   'nausea': 0.016376122556788168,
#   'stuffy nose': 0.03222222222222222,
#   'pharynx discomfort': 0.04271933853927423,
#   'runny nose': 0.027199320016999574,
#   'difficulty breathing': 0.03871681415929203,
#   'edema': 0.07281553398058252,
#   'palpitations': 0.025095057034220533,
#   'hoarse': 0.02023121387283237,
#   'hiccough': 0.018518518518518517,
#   'sweating': 0.018229166666666668,
#   'diarrhea': 0.017591339648173207,
#   'headache': 0.027263875365141188,
#   'fear of cold': 0.04241281809613572,
#   'feel sick and vomit': 0.020100502512562814,
#   'chills': 0.0288,
#   'chills and fever': 0.039755351681957186,
#   'rash': 0.014692378328741965,
#   'itching': 0.008934707903780068,
#   'night sweats': 0.054187192118226604,
#   'dizzy': 0.027777777777777776,
#   'sneeze': 0.02823920265780731,
#   'loss of appetite': 0.006472491909385114,
#   'dizziness': 0.010092514718250631,
#   'poor sleep': 0.05263157894736842,
#   'syncope': 0.01910828025477707,
#   'joint pain': 0.07692307692307693,
#   'cyanosis': 0.0070921985815602835,
#   'inspiratory tri-concave sign': 0.017543859649122806,
#   'poor spirits': 0.022222222222222223,
#   'fatigue': 0.03303303303303303,
#   'radiating pain': 0.1038961038961039,
#   'anorexia': 0.0196078431372549,
#   'burning sensation behind the breastbone': 0.0035335689045936395,
#   'hazy': 0.015706806282722512,
#   'backache': 0.011904761904761904,
#   'consciousness disorder': 0.004640371229698376,
#   'pain in front of neck': 0.006369426751592357,
#   'bloating': 0.025134649910233394,
#   'hard to swallow': 0.017241379310344827,
#   'twitch': 0.004405286343612335,
#   'earache': 0.005714285714285714,
#   'bitter': 0.02,
#   'body aches': 0.03968253968253968,
#   'thirst': 0.00975609756097561,
#   'waist pain': 0.009433962264150943,
#   'painful urination': 0.04081632653061224,
#   'nasal congestion': 0.016666666666666666,
#   'snore': 0.022222222222222223,
#   'proptosis': 0.007751937984496124,
#   'afraid of heat': 0.01694915254237288,
#   'constipation': 0.023809523809523808,
#   'abdominal pain and diarrhea': 0.08,
#   'ear itching': 0.0030911901081916537,
#   'right earache': 0.0048543689320388345,
#   'vertigo': 0.010050251256281407,
#   'hearing loss': 0.002699055330634278,
#   'tinnitus': 0.002317497103128621,
#   'itchy and uncomfortable eyes': 0.0021598272138228943,
#   'photophobia': 0.001594896331738437,
#   'jealous': 0.0017921146953405018,
#   'frequent urination': 0.03125,
#   'urgency': 0.033962264150943396,
#   'breast tenderness': 0.03486750348675035,
#   'redness': 0.029850746268656716,
#   'incontinence': 0.028985507246376812,
#   'hand tremor': 0.014084507042253521,
#   'thin': 0.004048582995951417,
#   'sleep disorder': 0.012345679012345678},
#  'chest tightness and shortness of breath': {'esophagitis': 0.0,
#   'enteritis': 0.0,
#   'asthma': 0.0,
#   'coronary heart disease': 0.0,
#   'pneumonia': 0.0,
#   'rhinitis': 0.0,
#   'thyroiditis': 0.0,
#   'traumatic brain injury': 0.0,
#   'dermatitis': 0.0,
#   'external otitis': 0.0,
#   'conjunctivitis': 0.0,
#   'mastitis': 0.0,
#   'shortness of breath': 0.13465987968533086,
#   'pain behind the breastbone': 0.03887089310504396,
#   'expectoration': 0.031004164738546967,
#   'chest tightness': 0.08513750731421885,
#   'hemoptysis': 0.040625,
#   'cough': 0.037232764833053086,
#   'vomiting': 0.02513696422816629,
#   'nausea': 0.021658742736397254,
#   'sweating': 0.033854166666666664,
#   'diarrhea': 0.02616147947677041,
#   'stomach ache': 0.026166593981683386,
#   'hiccough': 0.037037037037037035,
#   'pharynx discomfort': 0.01607717041800643,
#   'acid reflux': 0.016474464579901153,
#   'black stool': 0.034482758620689655,
#   'palpitations': 0.05095057034220532,
#   'fever': 0.02823018458197611,
#   'hematemesis': 0.043478260869565216,
#   'feel sick and vomit': 0.02763819095477387,
#   'bloating': 0.01436265709156194,
#   'dizziness': 0.02943650126156434,
#   'thin': 0.048582995951417005,
#   'burning sensation behind the breastbone': 0.014134275618374558,
#   'thin white moss': 0.056962025316455694,
#   'increased stool frequency': 0.047619047619047616,
#   'edema': 0.0825242718446602,
#   'headache': 0.016553067185978577,
#   'dizzy': 0.018518518518518517,
#   'cyanosis': 0.09219858156028368,
#   'defecate': 0.04878048780487805,
#   'stuffy nose': 0.025555555555555557,
#   'runny nose': 0.02847428814279643,
#   'bloody stools': 0.04,
#   'sneeze': 0.03322259136212625,
#   'loss of appetite': 0.02912621359223301,
#   'decreased urine output': 0.007575757575757576,
#   'twitch': 0.03671071953010279,
#   'chills': 0.0416,
#   'chills and fever': 0.04281345565749235,
#   'fear of cold': 0.03581526861451461,
#   'night sweats': 0.06896551724137931,
#   'difficulty breathing': 0.02765486725663717,
#   'suppuration': 0.03271028037383177,
#   'anorexia': 0.029411764705882353,
#   'fatigue': 0.018018018018018018,
#   'syncope': 0.03184713375796178,
#   'hazy': 0.020942408376963352,
#   'radiating pain': 0.012987012987012988,
#   'pain in front of neck': 0.012738853503184714,
#   'consciousness disorder': 0.004640371229698376,
#   'rash': 0.03489439853076217,
#   'hoarse': 0.04335260115606936,
#   'inspiratory tri-concave sign': 0.03508771929824561,
#   'poor spirits': 0.011111111111111112,
#   'itching': 0.021305841924398626,
#   'first degree swelling of bilateral tonsils': 0.010101010101010102,
#   'body aches': 0.023809523809523808,
#   'proptosis': 0.023255813953488372,
#   'shaking hands': 0.057692307692307696,
#   'constipation': 0.023809523809523808,
#   'hard to swallow': 0.013793103448275862,
#   'afraid of heat': 0.03389830508474576,
#   'afraid of cold': 0.023255813953488372,
#   'mild thyroid enlargement': 0.007462686567164179,
#   'frequent urination': 0.024305555555555556,
#   'hand tremor': 0.04225352112676056,
#   'poor sleep': 0.013157894736842105,
#   'head trauma pain': 0.010416666666666666,
#   'incontinence': 0.014492753623188406,
#   'unconsciousness': 0.0273972602739726,
#   'headache and dizziness': 0.00546448087431694,
#   'vertigo': 0.002512562814070352,
#   'poor physical activity': 0.041666666666666664,
#   'painful urination': 0.02040816326530612,
#   'urgency': 0.022641509433962263,
#   'congestion of skin and mucous membranes': 0.021739130434782608,
#   'ear itching': 0.0015455950540958269,
#   'earache': 0.002285714285714286,
#   'right earache': 0.0016181229773462784,
#   'tinnitus': 0.010428736964078795,
#   'itchy and uncomfortable eyes': 0.01079913606911447,
#   'cry': 0.006279434850863423,
#   'jealous': 0.007168458781362007,
#   'photophobia': 0.007974481658692184,
#   'breast tenderness': 0.043235704323570434,
#   'abdominal pain and diarrhea': 0.008,
#   'lumbago': 0.05555555555555555,
#   'redness': 0.014925373134328358,
#   'thirst': 0.004878048780487805,
#   'mucus pus and blood in the stool': 0.007874015748031496,
#   'tensile and heavy': 0.010101010101010102,
#   'hearing loss': 0.001349527665317139},
#  'chest tightness': {'esophagitis': 0.0,
#   'enteritis': 0.0,
#   'asthma': 0.0,
#   'coronary heart disease': 0.0,
#   'pneumonia': 0.0,
#   'rhinitis': 0.0,
#   'thyroiditis': 0.0,
#   'traumatic brain injury': 0.0,
#   'dermatitis': 0.0,
#   'external otitis': 0.0,
#   'conjunctivitis': 0.0,
#   'mastitis': 0.0,
#   'shortness of breath': 0.09742539496781744,
#   'pain behind the breastbone': 0.06173200702165009,
#   'expectoration': 0.03832650672908133,
#   'chest tightness and shortness of breath': 0.08513750731421885,
#   'hemoptysis': 0.06875,
#   'cough': 0.05789094403074706,
#   'acid reflux': 0.057660626029654036,
#   'burning sensation behind the breastbone': 0.038869257950530034,
#   'vomiting': 0.04189494038027715,
#   'nausea': 0.04384574749075541,
#   'sweating': 0.07291666666666667,
#   'diarrhea': 0.04059539918809202,
#   'stomach ache': 0.06061927605756651,
#   'pharynx discomfort': 0.02939825447864033,
#   'consciousness disorder': 0.030162412993039442,
#   'twitch': 0.04698972099853157,
#   'hiccup': 0.08433734939759036,
#   'hiccough': 0.046296296296296294,
#   'black stool': 0.05172413793103448,
#   'palpitations': 0.10798479087452471,
#   'fever': 0.04482705134170932,
#   'hematemesis': 0.043478260869565216,
#   'feel sick and vomit': 0.06030150753768844,
#   'bloating': 0.04129263913824058,
#   'dizziness': 0.05803195962994113,
#   'syncope': 0.12101910828025478,
#   'dizzy': 0.053703703703703705,
#   'thin': 0.05263157894736842,
#   'thin white moss': 0.056962025316455694,
#   'hard to swallow': 0.05517241379310345,
#   'poor spirits': 0.044444444444444446,
#   'increased stool frequency': 0.047619047619047616,
#   'hoarse': 0.05491329479768786,
#   'stuffy nose': 0.03222222222222222,
#   'runny nose': 0.03527411814704633,
#   'difficulty breathing': 0.09513274336283185,
#   'edema': 0.13592233009708737,
#   'headache': 0.03359298928919182,
#   'limb numbness': 0.08333333333333333,
#   'fatigue': 0.036036036036036036,
#   'cyanosis': 0.09219858156028368,
#   'defecate': 0.04878048780487805,
#   'backache': 0.11904761904761904,
#   'bloody stools': 0.04,
#   'sneeze': 0.04152823920265781,
#   'abdominal pain and diarrhea': 0.016,
#   'loss of appetite': 0.02912621359223301,
#   'decreased urine output': 0.007575757575757576,
#   'chills': 0.0512,
#   'chills and fever': 0.0581039755351682,
#   'fear of cold': 0.060320452403393024,
#   'night sweats': 0.08866995073891626,
#   'suppuration': 0.03271028037383177,
#   'anorexia': 0.049019607843137254,
#   'diplopia': 0.011494252873563218,
#   'nasal mucosal congestion': 0.018518518518518517,
#   'rash': 0.06060606060606061,
#   'joint pain': 0.07692307692307693,
#   'waist pain': 0.08490566037735849,
#   'radiating pain': 0.12987012987012986,
#   'hazy': 0.06282722513089005,
#   'vertigo': 0.007537688442211055,
#   'tinnitus': 0.013904982618771726,
#   'pain in front of neck': 0.01592356687898089,
#   'frequent urination': 0.03125,
#   'painful urination': 0.027210884353741496,
#   'urgency': 0.03018867924528302,
#   'inspiratory tri-concave sign': 0.03508771929824561,
#   'itching': 0.03917525773195876,
#   'first degree swelling of bilateral tonsils': 0.010101010101010102,
#   'body aches': 0.023809523809523808,
#   'proptosis': 0.046511627906976744,
#   'afraid of cold': 0.046511627906976744,
#   'afraid of heat': 0.0847457627118644,
#   'shaking hands': 0.07692307692307693,
#   'constipation': 0.023809523809523808,
#   'mild thyroid enlargement': 0.007462686567164179,
#   'hand tremor': 0.04225352112676056,
#   'poor sleep': 0.02631578947368421,
#   'head trauma pain': 0.020833333333333332,
#   'earache': 0.0034285714285714284,
#   'unconsciousness': 0.0547945205479452,
#   'incontinence': 0.028985507246376812,
#   'headache and dizziness': 0.01092896174863388,
#   'poor physical activity': 0.041666666666666664,
#   'congestion of skin and mucous membranes': 0.06521739130434782,
#   'ear itching': 0.0015455950540958269,
#   'right earache': 0.0016181229773462784,
#   'itchy and uncomfortable eyes': 0.01079913606911447,
#   'cry': 0.006279434850863423,
#   'jealous': 0.007168458781362007,
#   'photophobia': 0.007974481658692184,
#   'breast tenderness': 0.044630404463040445,
#   'lumbago': 0.05555555555555555,
#   'redness': 0.014925373134328358,
#   'thirst': 0.00975609756097561,
#   'mucus pus and blood in the stool': 0.007874015748031496,
#   'tensile and heavy': 0.010101010101010102,
#   'bitter': 0.02,
#   'hearing loss': 0.001349527665317139},
#  'hemoptysis': {'esophagitis': 0.015068416968694463,
#   'asthma': 0.09006997261513414,
#   'coronary heart disease': 0.034089205601308785,
#   'pneumonia': 0.03626932921534597,
#   'rhinitis': 0.019361653088266626,
#   'thyroiditis': 0.004006631101502574,
#   'shortness of breath': 0.109375,
#   'pain behind the breastbone': 0.103125,
#   'expectoration': 0.084375,
#   'chest tightness and shortness of breath': 0.040625,
#   'chest tightness': 0.06875,
#   'cough': 0.008647609896709103,
#   'pharynx discomfort': 0.007349563619660083,
#   'acid reflux': 0.004942339373970346,
#   'stomach ache': 0.0034888791975577847,
#   'fever': 0.006204436171862882,
#   'vomiting': 0.0016113438607798904,
#   'nausea': 0.002641310089804543,
#   'headache': 0.0034079844206426485,
#   'runny nose': 0.004249893752656183,
#   'difficulty breathing': 0.012168141592920354,
#   'diarrhea': 0.0022552999548940008,
#   'night sweats': 0.04926108374384237,
#   'fear of cold': 0.002827521206409048,
#   'palpitations': 0.00532319391634981,
#   'feel sick and vomit': 0.005025125628140704,
#   'stuffy nose': 0.0033333333333333335,
#   'edema': 0.009708737864077669,
#   'hiccough': 0.009259259259259259,
#   'burning sensation behind the breastbone': 0.007067137809187279,
#   'waist pain': 0.009433962264150943,
#   'sweating': 0.0026041666666666665,
#   'hoarse': 0.008670520231213872,
#   'sneeze': 0.0033222591362126247,
#   'bitter': 0.02,
#   'hard to swallow': 0.006896551724137931,
#   'fatigue': 0.0015015015015015015},
#  'cough': {'esophagitis': 0.0,
#   'enteritis': 0.0,
#   'asthma': 0.0,
#   'coronary heart disease': 0.0,
#   'pneumonia': 0.0,
#   'rhinitis': 0.0,
#   'thyroiditis': 0.0,
#   'traumatic brain injury': 0.0,
#   'dermatitis': 0.0,
#   'external otitis': 0.0,
#   'conjunctivitis': 0.0,
#   'mastitis': 0.0,
#   'shortness of breath': 0.0629353831371607,
#   'pain behind the breastbone': 0.025702618304107614,
#   'expectoration': 0.049243334134037954,
#   'chest tightness and shortness of breath': 0.037232764833053086,
#   'chest tightness': 0.05789094403074706,
#   'hemoptysis': 0.008647609896709103,
#   'acid reflux': 0.03459637561779242,
#   'burning sensation behind the breastbone': 0.0176678445229682,
#   'pharynx discomfort': 0.1157556270096463,
#   'hiccup': 0.060240963855421686,
#   'vomiting': 0.05671930389945214,
#   'nausea': 0.02641310089804543,
#   'sweating': 0.07291666666666667,
#   'diarrhea': 0.06811005863779883,
#   'stomach ache': 0.04404709986916703,
#   'fever': 0.08949899177912207,
#   'hiccough': 0.046296296296296294,
#   'black stool': 0.017241379310344827,
#   'palpitations': 0.05171102661596958,
#   'constipation': 0.047619047619047616,
#   'runny nose': 0.1155971100722482,
#   'twitch': 0.08516886930983847,
#   'hard to swallow': 0.06206896551724138,
#   'poor spirits': 0.08888888888888889,
#   'bloating': 0.03052064631956912,
#   'stuffy nose': 0.10666666666666667,
#   'difficulty breathing': 0.05530973451327434,
#   'edema': 0.0825242718446602,
#   'hoarse': 0.06647398843930635,
#   'dizziness': 0.025231286795626577,
#   'hematemesis': 0.021739130434782608,
#   'cyanosis': 0.10638297872340426,
#   'defecate': 0.0975609756097561,
#   'loss of appetite': 0.11974110032362459,
#   'sneeze': 0.11794019933554817,
#   'bloody stools': 0.08,
#   'headache': 0.04235637779941578,
#   'decreased urine output': 0.05303030303030303,
#   'mucus pus and blood in the stool': 0.023622047244094488,
#   'rash': 0.06978879706152434,
#   'cry': 0.02197802197802198,
#   'chills': 0.0656,
#   'increased stool frequency': 0.07142857142857142,
#   'chills and fever': 0.03669724770642202,
#   'fear of cold': 0.05560791705937795,
#   'itching': 0.04192439862542955,
#   'night sweats': 0.12807881773399016,
#   'first degree swelling of bilateral tonsils': 0.13131313131313133,
#   'suppuration': 0.11682242990654206,
#   'poor sleep': 0.07894736842105263,
#   'fatigue': 0.06606606606606606,
#   'anorexia': 0.029411764705882353,
#   'body aches': 0.09523809523809523,
#   'syncope': 0.03821656050955414,
#   'inspiratory tri-concave sign': 0.08771929824561403,
#   'feel sick and vomit': 0.022613065326633167,
#   'dizzy': 0.025925925925925925,
#   'radiating pain': 0.012987012987012988,
#   'hazy': 0.015706806282722512,
#   'backache': 0.03571428571428571,
#   'nasal congestion': 0.05,
#   'consciousness disorder': 0.016241299303944315,
#   'oliguria': 0.14285714285714285,
#   'frequent urination': 0.05555555555555555,
#   'painful urination': 0.06462585034013606,
#   'urgency': 0.052830188679245285,
#   'earache': 0.03314285714285714,
#   'bitter': 0.04,
#   'headache and dizziness': 0.00546448087431694,
#   'snore': 0.13333333333333333,
#   'nasal mucosal congestion': 0.05555555555555555,
#   'thin': 0.020242914979757085,
#   'thin white moss': 0.012658227848101266,
#   'waist pain': 0.02830188679245283,
#   'vertigo': 0.022613065326633167,
#   'thirst': 0.024390243902439025,
#   'ulcer': 0.11764705882352941,
#   'itchy eyes': 0.014778325123152709,
#   'blood in the tears': 0.03333333333333333,
#   'pain in front of neck': 0.08917197452229299,
#   'mild thyroid enlargement': 0.11194029850746269,
#   'proptosis': 0.007751937984496124,
#   'hand tremor': 0.04225352112676056,
#   'afraid of heat': 0.03389830508474576,
#   'head trauma pain': 0.005208333333333333,
#   'congestion of skin and mucous membranes': 0.021739130434782608,
#   'hematuria': 0.125,
#   'abdominal pain and diarrhea': 0.024,
#   'ear itching': 0.02627511591962906,
#   'right earache': 0.03398058252427184,
#   'hearing loss': 0.021592442645074223,
#   'tinnitus': 0.02085747392815759,
#   'nose bleeding': 0.0449438202247191,
#   'itchy and uncomfortable eyes': 0.02159827213822894,
#   'jealous': 0.017921146953405017,
#   'photophobia': 0.019138755980861243,
#   'eye pain': 0.003676470588235294,
#   'breast tenderness': 0.05578800557880056,
#   'redness': 0.029850746268656716,
#   'tensile and heavy': 0.020202020202020204,
#   'incontinence': 0.028985507246376812,
#   'sleep disorder': 0.012345679012345678},
#  'acid reflux': {'esophagitis': 0.33101415534126966,
#   'enteritis': 0.008983275012211448,
#   'asthma': 0.006090355940482338,
#   'coronary heart disease': 0.02061735248704267,
#   'pneumonia': 0.0031337005856551564,
#   'thyroiditis': 0.006231173418874992,
# ...
#   'edema': 0.0125,
#   'diplopia': 0.0125,
#   'cry': 0.1375,
#   'itchy eyes': 0.05,
#   'proptosis': 0.0375,
#   'shaking hands': 0.0125,
#   'hand tremor': 0.0125,
#   'itchy and uncomfortable eyes': 0.01511879049676026,
#   'photophobia': 0.019138755980861243,
#   'jealous': 0.017921146953405017,
#   'eye pain': 0.03308823529411765,
#   'vision loss': 0.010309278350515464},
#  'right earache': {'thyroiditis': 0.020713982303214508,
#   'external otitis': 0.9849438017978781,
#   'shortness of breath': 0.0016181229773462784,
#   'expectoration': 0.0048543689320388345,
#   'chest tightness and shortness of breath': 0.0016181229773462784,
#   'chest tightness': 0.0016181229773462784,
#   'cough': 0.03398058252427184,
#   'vomiting': 0.030744336569579287,
#   'nausea': 0.022653721682847898,
#   'stomach ache': 0.006472491909385114,
#   'pharynx discomfort': 0.022653721682847898,
#   'fever': 0.11003236245954692,
#   'hard to swallow': 0.0016181229773462784,
#   'palpitations': 0.003236245954692557,
#   'headache': 0.024271844660194174,
#   'dizziness': 0.01779935275080906,
#   'feel sick and vomit': 0.0016181229773462784,
#   'fear of cold': 0.003236245954692557,
#   'runny nose': 0.02912621359223301,
#   'dizzy': 0.003236245954692557,
#   'diplopia': 0.0016181229773462784,
#   'stuffy nose': 0.019417475728155338,
#   'hoarse': 0.003236245954692557,
#   'difficulty breathing': 0.008090614886731391,
#   'cry': 0.0016181229773462784,
#   'itching': 0.0970873786407767,
#   'tinnitus': 0.12459546925566344,
#   'vertigo': 0.045307443365695796,
#   'earache': 0.1553398058252427,
#   'hearing loss': 0.12135922330097088,
#   'ear itching': 0.09273570324574962,
#   'redness': 0.04477611940298507},
#  'vision loss': {'thyroiditis': 0.010356991151607254,
#   'conjunctivitis': 0.4726727434159899,
#   'vomiting': 0.05154639175257732,
#   'nausea': 0.05154639175257732,
#   'fever': 0.005154639175257732,
#   'headache': 0.041237113402061855,
#   'dizziness': 0.015463917525773196,
#   'feel sick and vomit': 0.010309278350515464,
#   'dizzy': 0.010309278350515464,
#   'cry': 0.18041237113402062,
#   'pain in front of neck': 0.005154639175257732,
#   'itchy eyes': 0.07216494845360824,
#   'hand tremor': 0.005154639175257732,
#   'eye swelling': 0.010309278350515464,
#   'itchy and uncomfortable eyes': 0.04103671706263499,
#   'jealous': 0.05197132616487455,
#   'photophobia': 0.06060606060606061,
#   'eye pain': 0.06985294117647059},
#  'unconsciousness': {'traumatic brain injury': 0.19327051720573338,
#   'shortness of breath': 0.0273972602739726,
#   'pain behind the breastbone': 0.0136986301369863,
#   'chest tightness and shortness of breath': 0.0273972602739726,
#   'chest tightness': 0.0547945205479452,
#   'vomiting': 0.1506849315068493,
#   'nausea': 0.1232876712328767,
#   'bloating': 0.0136986301369863,
#   'stomach ache': 0.0547945205479452,
#   'twitch': 0.0136986301369863,
#   'headache': 0.1643835616438356,
#   'dizziness': 0.1232876712328767,
#   'feel sick and vomit': 0.0410958904109589,
#   'cry': 0.0136986301369863,
#   'headache and dizziness': 0.0821917808219178,
#   'tinnitus': 0.0136986301369863,
#   'pain in front of neck': 0.0136986301369863,
#   'earache': 0.0136986301369863,
#   'nose bleeding': 0.0136986301369863,
#   'head trauma pain': 0.010416666666666666,
#   'poor physical activity': 0.041666666666666664},
#  'head trauma pain': {'traumatic brain injury': 0.7730820688229335,
#   'shortness of breath': 0.010416666666666666,
#   'pain behind the breastbone': 0.010416666666666666,
#   'chest tightness and shortness of breath': 0.010416666666666666,
#   'chest tightness': 0.020833333333333332,
#   'cough': 0.005208333333333333,
#   'vomiting': 0.16145833333333334,
#   'nausea': 0.11458333333333333,
#   'bloating': 0.005208333333333333,
#   'stomach ache': 0.026041666666666668,
#   'fever': 0.015625,
#   'consciousness disorder': 0.13541666666666666,
#   'twitch': 0.015625,
#   'palpitations': 0.005208333333333333,
#   'headache': 0.11979166666666667,
#   'dizziness': 0.109375,
#   'feel sick and vomit': 0.026041666666666668,
#   'fear of cold': 0.005208333333333333,
#   'dizzy': 0.06770833333333333,
#   'poor spirits': 0.005208333333333333,
#   'difficulty breathing': 0.005208333333333333,
#   'cry': 0.020833333333333332,
#   'headache and dizziness': 0.036458333333333336,
#   'waist pain': 0.005208333333333333,
#   'hazy': 0.005208333333333333,
#   'vertigo': 0.005208333333333333,
#   'pain in front of neck': 0.005208333333333333,
#   'unconsciousness': 0.010416666666666666,
#   'incontinence': 0.07246376811594203,
#   'redness': 0.014925373134328358,
#   'poor physical activity': 0.041666666666666664},
#  'redness': {'traumatic brain injury': 0.004863715207521666,
#   'dermatitis': 0.004974254189510795,
#   'external otitis': 0.030718201310663152,
#   'conjunctivitis': 0.005370973848796931,
#   'mastitis': 0.029845525137064767,
#   'shortness of breath': 0.014925373134328358,
#   'expectoration': 0.029850746268656716,
#   'chest tightness and shortness of breath': 0.014925373134328358,
#   'chest tightness': 0.014925373134328358,
#   'cough': 0.029850746268656716,
#   'vomiting': 0.029850746268656716,
#   'nausea': 0.029850746268656716,
#   'bloating': 0.014925373134328358,
#   'stomach ache': 0.014925373134328358,
#   'pharynx discomfort': 0.014925373134328358,
#   'fever': 0.1791044776119403,
#   'headache': 0.014925373134328358,
#   'dizzy': 0.014925373134328358,
#   'stuffy nose': 0.029850746268656716,
#   'chills': 0.014925373134328358,
#   'chills and fever': 0.014925373134328358,
#   'itching': 0.08955223880597014,
#   'tinnitus': 0.07462686567164178,
#   'earache': 0.05970149253731343,
#   'hearing loss': 0.08955223880597014,
#   'right earache': 0.04477611940298507,
#   'head trauma pain': 0.014925373134328358,
#   'ear itching': 0.0077279752704791345,
#   'jealous': 0.0017921146953405018,
#   'breast tenderness': 0.005578800557880056},
#  'poor physical activity': {'traumatic brain injury': 0.05522014777306668,
#   'shortness of breath': 0.041666666666666664,
#   'chest tightness and shortness of breath': 0.041666666666666664,
#   'chest tightness': 0.041666666666666664,
#   'vomiting': 0.16666666666666666,
#   'nausea': 0.08333333333333333,
#   'fever': 0.041666666666666664,
#   'headache': 0.125,
#   'dizziness': 0.125,
#   'difficulty breathing': 0.041666666666666664,
#   'headache and dizziness': 0.08333333333333333,
#   'waist pain': 0.041666666666666664,
#   'vertigo': 0.041666666666666664,
#   'hearing loss': 0.041666666666666664,
#   'unconsciousness': 0.041666666666666664,
#   'head trauma pain': 0.041666666666666664},
#  'congestion of skin and mucous membranes': {'dermatitis': 0.16942545339463638,
#   'shortness of breath': 0.021739130434782608,
#   'chest tightness and shortness of breath': 0.021739130434782608,
#   'chest tightness': 0.06521739130434782,
#   'cough': 0.021739130434782608,
#   'stomach ache': 0.021739130434782608,
#   'fever': 0.17391304347826086,
#   'palpitations': 0.043478260869565216,
#   'headache': 0.043478260869565216,
#   'fear of cold': 0.10869565217391304,
#   'dizzy': 0.043478260869565216,
#   'rash': 0.13043478260869565,
#   'itching': 0.21739130434782608,
#   'papule': 0.4},
#  'papule': {'dermatitis': 0.05647515113154546,
#   'stomach ache': 0.1,
#   'fever': 0.2,
#   'fear of cold': 0.1,
#   'itching': 0.2,
#   'congestion of skin and mucous membranes': 0.4},
#  'dysmenorrhea': {'dermatitis': 0.014118787782886366,
#   'rash': 0.25,
#   'waist pain': 0.25,
#   'itching': 0.25,
#   'breast tenderness': 0.001394700139470014},
#  'breast tenderness': {'dermatitis': 0.007876672506363015,
#   'conjunctivitis': 0.008504873381103624,
#   'mastitis': 0.9058173382317467,
#   'shortness of breath': 0.043235704323570434,
#   'pain behind the breastbone': 0.019525801952580194,
#   'expectoration': 0.03486750348675035,
#   'chest tightness and shortness of breath': 0.043235704323570434,
#   'chest tightness': 0.044630404463040445,
#   'cough': 0.05578800557880056,
#   'vomiting': 0.015341701534170154,
#   'nausea': 0.015341701534170154,
#   'bloating': 0.011157601115760111,
#   'diarrhea': 0.03347280334728033,
#   'stomach ache': 0.04184100418410042,
#   'pharynx discomfort': 0.03905160390516039,
#   'fatigue': 0.002789400278940028,
#   'fever': 0.15481171548117154,
#   'consciousness disorder': 0.0041841004184100415,
#   'twitch': 0.005578800557880056,
#   'thin': 0.008368200836820083,
#   'palpitations': 0.015341701534170154,
#   'headache': 0.08089260808926081,
#   'dizziness': 0.023709902370990237,
#   'feel sick and vomit': 0.001394700139470014,
#   'fear of cold': 0.06694560669456066,
#   'runny nose': 0.04741980474198047,
#   'dizzy': 0.001394700139470014,
#   'thin white moss': 0.008368200836820083,
#   'stuffy nose': 0.043235704323570434,
#   'hoarse': 0.001394700139470014,
#   'difficulty breathing': 0.002789400278940028,
#   'body aches': 0.005578800557880056,
#   'loss of appetite': 0.001394700139470014,
#   'frequent urination': 0.01394700139470014,
#   'abdominal pain and diarrhea': 0.001394700139470014,
#   'chills': 0.029288702928870293,
#   'rash': 0.001394700139470014,
#   'chills and fever': 0.022315202231520222,
#   'waist pain': 0.00697350069735007,
#   'lumbago': 0.002789400278940028,
#   'urgency': 0.01394700139470014,
#   'painful urination': 0.019525801952580194,
#   'itching': 0.001394700139470014,
#   'tinnitus': 0.005578800557880056,
#   'afraid of cold': 0.001394700139470014,
#   'redness': 0.005578800557880056,
#   'dysmenorrhea': 0.001394700139470014},
#  'photophobia': {'dermatitis': 0.020360903059409716,
#   'conjunctivitis': 1.4509953983932715,
#   'shortness of breath': 0.007974481658692184,
#   'expectoration': 0.001594896331738437,
#   'chest tightness and shortness of breath': 0.007974481658692184,
#   'chest tightness': 0.007974481658692184,
#   'cough': 0.019138755980861243,
#   'vomiting': 0.02711323763955343,
#   'nausea': 0.019138755980861243,
#   'bloating': 0.001594896331738437,
#   'diarrhea': 0.004784688995215311,
#   'stomach ache': 0.004784688995215311,
#   'pharynx discomfort': 0.023923444976076555,
#   'fatigue': 0.001594896331738437,
#   'sweating': 0.001594896331738437,
#   'fever': 0.08133971291866028,
#   'twitch': 0.001594896331738437,
#   'palpitations': 0.001594896331738437,
#   'headache': 0.030303030303030304,
#   'dizziness': 0.009569377990430622,
#   'feel sick and vomit': 0.003189792663476874,
#   'runny nose': 0.011164274322169059,
#   'dizzy': 0.003189792663476874,
#   'edema': 0.001594896331738437,
#   'stuffy nose': 0.009569377990430622,
#   'hoarse': 0.001594896331738437,
#   'difficulty breathing': 0.001594896331738437,
#   'cyanosis': 0.004784688995215311,
#   'chills': 0.001594896331738437,
#   'sneeze': 0.001594896331738437,
#   'rash': 0.003189792663476874,
#   'cry': 0.17543859649122806,
#   'itching': 0.001594896331738437,
#   'inspiratory tri-concave sign': 0.001594896331738437,
#   'hazy': 0.030303030303030304,
#   'itchy eyes': 0.051036682615629984,
#   'afraid of heat': 0.001594896331738437,
#   'eye swelling': 0.019138755980861243,
#   'vision loss': 0.06060606060606061,
#   'jealous': 0.18100358422939067,
#   'eye pain': 0.18382352941176472,
#   'itchy and uncomfortable eyes': 0.16414686825053995},
#  'jealous': {'dermatitis': 0.020360903059409716,
#   'conjunctivitis': 1.264124778903229,
#   'shortness of breath': 0.007168458781362007,
#   'expectoration': 0.0017921146953405018,
#   'chest tightness and shortness of breath': 0.007168458781362007,
#   'chest tightness': 0.007168458781362007,
#   'cough': 0.017921146953405017,
#   'vomiting': 0.02867383512544803,
#   'nausea': 0.021505376344086023,
#   'bloating': 0.0017921146953405018,
#   'diarrhea': 0.0035842293906810036,
#   'stomach ache': 0.005376344086021506,
#   'pharynx discomfort': 0.023297491039426525,
#   'fatigue': 0.0017921146953405018,
#   'fever': 0.07168458781362007,
#   'twitch': 0.0017921146953405018,
#   'headache': 0.03046594982078853,
#   'dizziness': 0.012544802867383513,
#   'feel sick and vomit': 0.0035842293906810036,
#   'runny nose': 0.012544802867383513,
#   'dizzy': 0.0035842293906810036,
#   'diplopia': 0.0017921146953405018,
#   'stuffy nose': 0.008960573476702509,
#   'hoarse': 0.0017921146953405018,
#   'difficulty breathing': 0.0017921146953405018,
#   'cyanosis': 0.005376344086021506,
#   'chills': 0.0017921146953405018,
#   'rash': 0.0035842293906810036,
#   'cry': 0.16308243727598568,
#   'itching': 0.0017921146953405018,
#   'hazy': 0.025089605734767026,
#   'itchy eyes': 0.053763440860215055,
#   'eye swelling': 0.017921146953405017,
#   'vision loss': 0.05197132616487455,
#   'redness': 0.0017921146953405018,
#   'photophobia': 0.18100358422939067,
#   'eye pain': 0.17279411764705882,
#   'itchy and uncomfortable eyes': 0.15766738660907129},
#  'eye pain': {'dermatitis': 0.010180451529704858,
#   'conjunctivitis': 0.6485509735242653,
#   'cough': 0.003676470588235294,
#   'vomiting': 0.014705882352941176,
#   'nausea': 0.014705882352941176,
#   'pharynx discomfort': 0.003676470588235294,
#   'fever': 0.03308823529411765,
#   'headache': 0.029411764705882353,
#   'runny nose': 0.003676470588235294,
#   'diplopia': 0.003676470588235294,
#   'stuffy nose': 0.003676470588235294,
#   'rash': 0.003676470588235294,
#   'cry': 0.16544117647058823,
#   'itching': 0.003676470588235294,
#   'hazy': 0.04044117647058824,
#   'itchy eyes': 0.07720588235294118,
#   'eye swelling': 0.03308823529411765,
#   'vision loss': 0.06985294117647059,
#   'photophobia': 0.18382352941176472,
#   'jealous': 0.17279411764705882,
#   'itchy and uncomfortable eyes': 0.08207343412526998},
#  'itchy and uncomfortable eyes': {'dermatitis': 0.010180451529704858,
#   'conjunctivitis': 0.9453454868319798,
#   'shortness of breath': 0.01079913606911447,
#   'expectoration': 0.0021598272138228943,
#   'chest tightness and shortness of breath': 0.01079913606911447,
#   'chest tightness': 0.01079913606911447,
#   'cough': 0.02159827213822894,
#   'vomiting': 0.03023758099352052,
#   'nausea': 0.019438444924406047,
#   'bloating': 0.0021598272138228943,
#   'diarrhea': 0.0064794816414686825,
#   'stomach ache': 0.0064794816414686825,
#   'pharynx discomfort': 0.017278617710583154,
#   'fatigue': 0.0021598272138228943,
#   'fever': 0.06695464362850972,
#   'twitch': 0.0021598272138228943,
#   'headache': 0.032397408207343416,
#   'dizziness': 0.01511879049676026,
#   'feel sick and vomit': 0.004319654427645789,
#   'runny nose': 0.01079913606911447,
#   'dizzy': 0.004319654427645789,
#   'diplopia': 0.0021598272138228943,
#   'stuffy nose': 0.01079913606911447,
#   'hoarse': 0.0021598272138228943,
#   'difficulty breathing': 0.0021598272138228943,
#   'cyanosis': 0.0064794816414686825,
#   'chills': 0.0021598272138228943,
#   'rash': 0.0021598272138228943,
#   'cry': 0.15766738660907129,
#   'inspiratory tri-concave sign': 0.0021598272138228943,
#   'hazy': 0.032397408207343416,
#   'itchy eyes': 0.04319654427645788,
#   'eye swelling': 0.01511879049676026,
#   'vision loss': 0.04103671706263499,
#   'photophobia': 0.16414686825053995,
#   'jealous': 0.15766738660907129,
#   'eye pain': 0.08207343412526998},
#  'ear itching': {'external otitis': 1.4240985478317194,
#   'shortness of breath': 0.0015455950540958269,
#   'expectoration': 0.0030911901081916537,
#   'chest tightness and shortness of breath': 0.0015455950540958269,
#   'chest tightness': 0.0015455950540958269,
#   'cough': 0.02627511591962906,
#   'vomiting': 0.027820710973724884,
#   'nausea': 0.02009273570324575,
#   'diarrhea': 0.0015455950540958269,
#   'stomach ache': 0.00463678516228748,
#   'pharynx discomfort': 0.017001545595054096,
#   'fever': 0.11591962905718702,
#   'palpitations': 0.0061823802163833074,
#   'headache': 0.02009273570324575,
#   'dizziness': 0.02009273570324575,
#   'feel sick and vomit': 0.0030911901081916537,
#   'fear of cold': 0.00463678516228748,
#   'runny nose': 0.027820710973724884,
#   'dizzy': 0.0015455950540958269,
#   'diplopia': 0.00463678516228748,
#   'stuffy nose': 0.017001545595054096,
#   'hoarse': 0.0030911901081916537,
#   'difficulty breathing': 0.00927357032457496,
#   'sneeze': 0.0015455950540958269,
#   'cry': 0.0015455950540958269,
#   'itching': 0.15146831530139104,
#   'nasal mucosal congestion': 0.0015455950540958269,
#   'tinnitus': 0.10973724884080371,
#   'vertigo': 0.04173106646058733,
#   'earache': 0.12364760432766615,
#   'itchy eyes': 0.0015455950540958269,
#   'nose bleeding': 0.0030911901081916537,
#   'hearing loss': 0.12210200927357033,
#   'swelling of both nasal mucosa': 0.0030911901081916537,
#   'right earache': 0.09273570324574962,
#   'redness': 0.0077279752704791345}}

# %%
new_mddial_kg = {}

for outer_key, nested in mddial_kg.items():
    new_outer_key = merged_symptom_disease_map.get(outer_key, outer_key)

    new_nested = {}
    for key, value in nested.items():
        new_key = merged_symptom_disease_map.get(key, key)
        new_nested[new_key] = value

    new_mddial_kg[new_outer_key] = new_nested
mddial_kg = new_mddial_kg

# %%
with open("/path-to-folder/SD++.p","wb") as f:
    pickle.dump(mddial_kg,f)

# %%
symptom_disease_map = {}
for source, targets in mddial_kg.items():
    for target, weight in targets.items():
        if source.startswith('S_') and target.startswith('D_') and weight > 0:
            if source not in symptom_disease_map:
                symptom_disease_map[source] = []
            symptom_disease_map[source].append((target, weight))

y_true = []
y_pred = []

for dialog in mddial_dialogs_mapped:
    disease_true = list(dialog.keys())[0]
    symptoms = dialog[disease_true]

    # Create graph
    G = nx.DiGraph()

    # Add user and symptom edges
    for symptom in symptoms:
        G.add_edge("User", symptom, weight=1.0)

    # Find diseases connected to ALL symptoms (intersection-based filtering)
    if symptoms:
        # Get diseases for first symptom
        valid_diseases = set()
        first_symptom = symptoms[0]
        for (disease, weight) in symptom_disease_map.get(first_symptom, []):
            valid_diseases.add(disease)

        # Intersect with diseases from remaining symptoms
        for symptom in symptoms[1:]:
            symptom_diseases = set([disease for (disease, weight) in symptom_disease_map.get(symptom, [])])
            valid_diseases = valid_diseases.intersection(symptom_diseases)
    else:
        valid_diseases = set()

    # Add edges from symptoms to diseases ONLY if disease is in valid_diseases
    for symptom in symptoms:
        for (disease, weight) in symptom_disease_map.get(symptom, []):
            if disease in valid_diseases:
                G.add_edge(symptom, disease, weight=weight)

    # Run Personalized PageRank
    ppr = nx.pagerank(G, personalization={"User": 1.0}, alpha=0.85, weight='weight')

    # Filter for only disease nodes
    disease_scores = {node: score for node, score in ppr.items() if node.startswith('D_')}

    if not disease_scores:
        predicted_disease = None
    else:
        predicted_disease = max(disease_scores, key=disease_scores.get)

    y_true.append(disease_true)
    y_pred.append(predicted_disease)

filtered_true = []
filtered_pred = []

for t, p in zip(y_true, y_pred):
    if p is not None:
        filtered_true.append(t)
        filtered_pred.append(p)

accuracy = accuracy_score(filtered_true, filtered_pred)
precision = precision_score(filtered_true, filtered_pred, average='macro', zero_division=0)
recall = recall_score(filtered_true, filtered_pred, average='macro', zero_division=0)
f1 = f1_score(filtered_true, filtered_pred, average='macro', zero_division=0)

print("Evaluation Results:")
print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1 Score : {f1:.4f}")
# Out:
# Evaluation Results:
# Accuracy : 0.9529
# Precision: 0.8179
# Recall   : 0.7965
# F1 Score : 0.8034
